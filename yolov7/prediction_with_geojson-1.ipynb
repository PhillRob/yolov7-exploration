# %%
import rasterio
import os
from rasterio.windows import Window
import cv2

from osgeo import gdal
import numpy as np
from matplotlib import pyplot as plt
import torch
import argparse
import time
import json
from pathlib import Path
import torch.backends.cudnn as cudnn
from numpy import random
from icecream import ic
import geojson
import tempfile
from geojson import Point, Feature, FeatureCollection, dump

import sys
sys.path.append('yolov7')


from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages
from utils.general import check_img_size, check_requirements, check_imshow, non_max_suppression, apply_classifier, \
    scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
from utils.plots import plot_one_box
from utils.torch_utils import select_device, load_classifier, time_synchronized, TracedModel

# %%
class detect_piles():
  def __init__(self, weights):
    self.device = select_device('')

    # load FP32 model
    self.model = attempt_load(weights, map_location=self.device)
    print("Model Loaded")


  def detect(self, source_path, pred_saving_path, imgsize = 640, view_img_flag = False, save_img=False, trace_flag = False):

    all_boxes = []

    conf_thres = 0.5
    iou_thres = 0.45
    classes = None
    agnostic_nms = False
    save_conf = False
    save_txt = True
    nosave = False
    save_dir = pred_saving_path

    source, view_img, imgsz, trace = source_path, view_img_flag, imgsize, trace_flag
    
    save_img = not nosave and not source.endswith('.txt')
    # webcam = source.isnumeric() or source.endswith('.txt') or source.lower().startswith(('rtsp://', 'rtmp://', 'http://', 'https://'))
    webcam = False
    set_logging()
    half = self.device.type != 'cpu'

      
    stride = int(self.model.stride.max())  # model stride
    imgsz = check_img_size(imgsz, s=stride) 
    img_size = 640
    
    if trace:
      self.model = TracedModel(self.model, self.device, img_size)
    if half:
      self.model.half()

    classify = False

    if classify:
      modelc = load_classifier(name='resnet101', n=2)  # initialize
      modelc.load_state_dict(torch.load('weights/resnet101.pt', map_location=self.device)['model']).to(self.device).eval()

    vid_path, vid_writer = None, None

    if webcam:
      view_img = check_imshow()
      cudnn.benchmark = True  # set True to speed up constant image size inference
      dataset = LoadStreams(source, img_size=imgsz, stride=stride)

    else:
      dataset = LoadImages(source, img_size=imgsz, stride=stride)
    
    names = self.model.module.names if hasattr(self.model, 'module') else self.model.names
    # colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]
    colors = [[0,0,255]]

    if self.device.type != 'cpu':
      self.model(torch.zeros(1, 3, imgsz, imgsz).to(self.device).type_as(next(self.model.parameters())))  # run once
    old_img_w = old_img_h = imgsz
    old_img_b = 1
    augment = False
    t0 = time.time()

    for path, img, im0s, vid_cap in dataset:
      img = torch.from_numpy(img).to(self.device)
      img = img.half() if half else img.float()  # uint8 to fp16/32
      img /= 255.0  # 0 - 255 to 0.0 - 1.0

      if img.ndimension() == 3:
        img = img.unsqueeze(0)

      if self.device.type != 'cpu' and (old_img_b != img.shape[0] or old_img_h != img.shape[2] or old_img_w != img.shape[3]):
        old_img_b = img.shape[0]
        old_img_h = img.shape[2]
        old_img_w = img.shape[3]

        for i in range(3):
          self.model(img, augment=augment)[0]

      t1 = time_synchronized()

      with torch.no_grad():     # Calculating gradients would cause a GPU memory leak
        pred = self.model(img, augment=augment)[0]
      t2 = time_synchronized()
      pred = non_max_suppression(pred, conf_thres, iou_thres, classes=classes, agnostic=agnostic_nms)
      t3 = time_synchronized()

      if classify:
        pred = apply_classifier(pred, modelc, img, im0s)

      for i, det in enumerate(pred):
        if webcam:
          p, s, im0, frame = path[i], '%g: ' % i, im0s[i].copy(), dataset.count
        else:
          p, s, im0, frame = path, '', im0s, getattr(dataset, 'frame', 0)
        p = Path(p)
        save_path = save_dir + "/" + p.name
        # txt_path = str(save_dir + "/" + p.stem) + ('' if dataset.mode == 'image' else f'_{frame}')
        gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
        if len(det):
          det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()
          for c in det[:, -1].unique():
            n = (det[:, -1] == c).sum()
            s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "
          for *xyxy, conf, cls in reversed(det):
            if save_txt:
              xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()
              all_boxes.append([xywh[0], xywh[1], xywh[2], xywh[3]])
              line = (cls, *xywh, conf) if save_conf else (cls, *xywh)
              # with open(txt_path + '.txt', 'a') as f:
              #   f.write(('%g ' * len(line)).rstrip() % line + '\n')

            if save_img or view_img:
              label = f'{names[int(cls)]} {conf:.2f}'
              plot_one_box(xyxy, im0, label=label, color=colors[int(cls)], line_thickness=1)
        # print(f'{s}Done. ({(1E3 * (t2 - t1)):.1f}ms) Inference, ({(1E3 * (t3 - t2)):.1f}ms) NMS')
        if view_img:
          cv2.imshow(str(p), im0)
          cv2.waitKey(1)
        ww, hh = im0.shape[1], im0.shape[0]  
        if save_img:
          if dataset.mode == 'image':
            cv2.imwrite(save_path, im0)
            print(f" The image with the result is saved in: {save_path}")
          else: 
            if vid_path != save_path:
              vid_path = save_path
              if isinstance(vid_writer, cv2.VideoWriter):
                vid_writer.release()
              if vid_cap:
                fps = vid_cap.get(cv2.CAP_PROP_FPS)
                w = int(vid_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                h = int(vid_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
              else: 
                fps, w, h = 30, im0.shape[1], im0.shape[0]
                save_path += '.mp4'
              vid_writer = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))
            vid_writer.write(im0)  
    return all_boxes, ww, hh

# %%
class get_predictions():
  def __init__(self, w_path):
    self.pile_class = detect_piles(w_path)

  def convert_img_array(self, data):
    data = torch.from_numpy(data)
    data=data.permute(1, 2, 0)
    data = data.numpy()
    data = cv2.cvtColor(data, cv2.COLOR_BGR2RGB)
    return data

  def yolo2bbox(self, x, y, w, h, img_height, img_width):
    x = float(x)
    y = float(y)
    w = float(w)
    h = float(h)
    img_height = float(img_height)
    img_width = float(img_width)
    height = h * img_height
    width = w * img_width
    left = (x * img_width) - (width // 2)
    top = (y * img_height) - (height // 2)
    return round(top), round(left), round(height), round(width)

  def resetXY(self, list_of_box, img_h, img_w, org_x, org_y):
    convert_x_y = []
    for i in list_of_box:
      y,x,h,w = self.yolo2bbox(i[0], i[1], i[2], i[3], img_h, img_w)
      convert_x_y.append([x+org_x,y+org_y,w,h])
    return convert_x_y


  def generate_points(self, cor_list):
    cnt = 0
    final_data = []
    for i in cor_list:
      tmp = {"id": "",
            "coord": ""}
      x,y,w,h = i
      p = [x,y]
      sp = [x+w, y]
      tp = [x+w, y+h]
      fp = [x, y+h]
      tmp["id"] = cnt
      tmp["coord"] = [p, sp, tp, fp]
      final_data.append(tmp)
      cnt += 1
    return final_data


  def convertUTM(self, file_path, list_of_coord):
    ds = gdal.Open(file_path)

    cnt = 0
    final_data = []
    gt = ds.GetGeoTransform()
    c, a, b, f, d, e = gt
    for i in list_of_coord:
      tmp_list = []
      tmp = {"id": "",
            "coord": ""}
      for k in i["coord"]:
        x, y = k[0], k[1]
        east = c+(a*x)
        north = f+(e*y)
        tmp_list.append([east, north])
      tmp["id"], tmp["coord"] = cnt, tmp_list
      final_data.append(tmp)
      cnt += 1
    return final_data

  def write_json(self, features):
      # feature is a shapely geometry type
      geom_in_geojson = geojson.Feature(geometry=features, properties={})
      tmp_file = tempfile.mkstemp(suffix='.geojson')
      with open(tmp_file[1], 'w') as outfile:
          geojson.dump(geom_in_geojson, outfile)
      return tmp_file[1]


  def generate_crops(self, file_path, pred_path, json_save_path, tmp_folder, crop_size=2500):
    stop_flag = False

    if not os.path.exists(json_save_path):
      print("Not Found GeoJson Saving Path.. \n Creating GeoJson File Saving Path...")
      os.makedirs(json_save_path)

    if not os.path.exists(tmp_folder):
      print("not found tmp folder.. \n creating tmp folder...")
      os.makedirs(tmp_folder)

    if not os.path.exists(pred_path):
      print("not found directory for saving pedicted images.. \n creating directory...")
      os.makedirs(pred_path)

    

    file_name = file_path.split("/")[-1].split(".")[0]
    features = []


    id = 0


    img = rasterio.open(file_path)
    profile = img.profile

    width = profile["width"]
    height = profile["height"]

    print("Total Width = ", width, "Total Height = ", height)

    width_cut = crop_size
    height_cut = crop_size
    step = crop_size
    cnt_ = 0
    

    for col in range(0, height, step):
      if col + step >= height:
        height_cut = abs(height - col)
      
      for row in range(0, width, step):

        if row+width_cut >= width:
          final_cut =  abs(width - row)            
          data = img.read([1,2,3], window=Window(row,col, final_cut, height_cut))
          final_img = self.convert_img_array(data)
          cv2.imwrite(f'{tmp_folder}/img_{cnt_}.png', final_img)
          sam = f'{tmp_folder}/img_{cnt_}.png'
          pred_boxes, img_w, img_h = self.pile_class.detect(sam, pred_path)
          reset_cord = self.resetXY(pred_boxes, img_h, img_w, row, col)
          generate_cord = self.generate_points(reset_cord)
          converted_cord = self.convertUTM(file_path, generate_cord)
          if len(converted_cord) > 0:
            
            for i in converted_cord:
              i["coord"].append(i["coord"][0])
              point = Point([i["coord"]])
              point["type"] = "Polygon"
              
              area = abs((i["coord"][1][0] - i["coord"][0][0]) * (i["coord"][2][1] - i["coord"][1][1]))
              width_ = abs(i["coord"][1][0] - i["coord"][0][0])
              height_= abs(i["coord"][2][1] - i["coord"][1][1])
              perimeter = 2*abs((i["coord"][1][0] - i["coord"][0][0]) * (i["coord"][2][1] - i["coord"][1][1]))
              
              features.append(Feature(geometry=point, properties={"id":id, "Polyg_Area":area, "area":area, "width":width_, "height":height_,"perimeter":perimeter}))
              id += 1


          os.remove(sam)
          cnt_ += 1

        else:
          data = img.read([1,2,3], window=Window(row,col, width_cut, height_cut))
          final_img = self.convert_img_array(data)
          cv2.imwrite(f'{tmp_folder}/img_{cnt_}.png', final_img)
          sam = f'{tmp_folder}/img_{cnt_}.png'
          pred_boxes, img_w, img_h = self.pile_class.detect(sam, pred_path)
          reset_cord = self.resetXY(pred_boxes, img_h, img_w, row, col)
          generate_cord = self.generate_points(reset_cord)
          converted_cord = self.convertUTM(file_path, generate_cord)
          if len(converted_cord) > 0:
            for i in converted_cord:
              i["coord"].append(i["coord"][0])
              point = Point([i["coord"]])
              point["type"] = "Polygon"

                
              area = abs((i["coord"][1][0] - i["coord"][0][0]) * (i["coord"][2][1] - i["coord"][1][1]))
              width_ = abs(i["coord"][1][0] - i["coord"][0][0])
              height_ = abs(i["coord"][2][1] - i["coord"][1][1])
              perimeter = 2*abs((i["coord"][1][0] - i["coord"][0][0]) * (i["coord"][2][1] - i["coord"][1][1]))
              
              features.append(Feature(geometry=point, properties={"id":id, "Polyg_Area":area, "area":area, "width":width_, "height":height_,"perimeter":perimeter}))
              id += 1


          os.remove(sam)
          cnt_ += 1
    feature_collection = FeatureCollection(features)
    

    feature_collection["name"] = file_name
    feature_collection["crs"] = { "type": "name", "properties": { "name": "urn:ogc:def:crs:EPSG::32638" } }
    with open(f"{json_save_path}/{file_name}.geojson", 'w') as f:
      dump(feature_collection, f)
    return feature_collection

# %%
tiff_file1 = "/content/drive/MyDrive/Khantil/Dump_Detection/Data_Preprocess/tiff_files/NamarDaharat1_Orthomosaic_export_TueAug23092916168449.tif"
weights_path = "yolov7/runs/train/only_annoted_data/weights/best.pt"

save_pred_path = "viral_test/yolo_detected"
json_savin_path  = "viral_test/generated_geo_files"
tmp_file_path = "viral_test/tmp" # use for Store images which will go to yolo model for prediction and then remove it

# %%
obj = get_predictions(weights_path)
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Loaded

# %%
file_json = obj.generate_crops(tiff_file1, save_pred_path, json_savin_path, tmp_file_path)
# Out:
# Total Width =  52202 Total Height =  51919
#  The image with the result is saved in: viral_test/yolo_detected/img_0.png
#  The image with the result is saved in: viral_test/yolo_detected/img_1.png
#  The image with the result is saved in: viral_test/yolo_detected/img_2.png
#  The image with the result is saved in: viral_test/yolo_detected/img_3.png
#  The image with the result is saved in: viral_test/yolo_detected/img_4.png
#  The image with the result is saved in: viral_test/yolo_detected/img_5.png
#  The image with the result is saved in: viral_test/yolo_detected/img_6.png
#  The image with the result is saved in: viral_test/yolo_detected/img_7.png
#  The image with the result is saved in: viral_test/yolo_detected/img_8.png
#  The image with the result is saved in: viral_test/yolo_detected/img_9.png
#  The image with the result is saved in: viral_test/yolo_detected/img_10.png
#  The image with the result is saved in: viral_test/yolo_detected/img_11.png
#  The image with the result is saved in: viral_test/yolo_detected/img_12.png
#  The image with the result is saved in: viral_test/yolo_detected/img_13.png
#  The image with the result is saved in: viral_test/yolo_detected/img_14.png
#  The image with the result is saved in: viral_test/yolo_detected/img_15.png
#  The image with the result is saved in: viral_test/yolo_detected/img_16.png
#  The image with the result is saved in: viral_test/yolo_detected/img_17.png
#  The image with the result is saved in: viral_test/yolo_detected/img_18.png
#  The image with the result is saved in: viral_test/yolo_detected/img_19.png
#  The image with the result is saved in: viral_test/yolo_detected/img_20.png
#  The image with the result is saved in: viral_test/yolo_detected/img_21.png
#  The image with the result is saved in: viral_test/yolo_detected/img_22.png
#  The image with the result is saved in: viral_test/yolo_detected/img_23.png
#  The image with the result is saved in: viral_test/yolo_detected/img_24.png
#  The image with the result is saved in: viral_test/yolo_detected/img_25.png
#  The image with the result is saved in: viral_test/yolo_detected/img_26.png
#  The image with the result is saved in: viral_test/yolo_detected/img_27.png
#  The image with the result is saved in: viral_test/yolo_detected/img_28.png
#  The image with the result is saved in: viral_test/yolo_detected/img_29.png
#  The image with the result is saved in: viral_test/yolo_detected/img_30.png
#  The image with the result is saved in: viral_test/yolo_detected/img_31.png
#  The image with the result is saved in: viral_test/yolo_detected/img_32.png
#  The image with the result is saved in: viral_test/yolo_detected/img_33.png
#  The image with the result is saved in: viral_test/yolo_detected/img_34.png
#  The image with the result is saved in: viral_test/yolo_detected/img_35.png
#  The image with the result is saved in: viral_test/yolo_detected/img_36.png
#  The image with the result is saved in: viral_test/yolo_detected/img_37.png
#  The image with the result is saved in: viral_test/yolo_detected/img_38.png
#  The image with the result is saved in: viral_test/yolo_detected/img_39.png
#  The image with the result is saved in: viral_test/yolo_detected/img_40.png
#  The image with the result is saved in: viral_test/yolo_detected/img_41.png
#  The image with the result is saved in: viral_test/yolo_detected/img_42.png
#  The image with the result is saved in: viral_test/yolo_detected/img_43.png
#  The image with the result is saved in: viral_test/yolo_detected/img_44.png
#  The image with the result is saved in: viral_test/yolo_detected/img_45.png
#  The image with the result is saved in: viral_test/yolo_detected/img_46.png
#  The image with the result is saved in: viral_test/yolo_detected/img_47.png
#  The image with the result is saved in: viral_test/yolo_detected/img_48.png
#  The image with the result is saved in: viral_test/yolo_detected/img_49.png
#  The image with the result is saved in: viral_test/yolo_detected/img_50.png
#  The image with the result is saved in: viral_test/yolo_detected/img_51.png
#  The image with the result is saved in: viral_test/yolo_detected/img_52.png
#  The image with the result is saved in: viral_test/yolo_detected/img_53.png
#  The image with the result is saved in: viral_test/yolo_detected/img_54.png
#  The image with the result is saved in: viral_test/yolo_detected/img_55.png
#  The image with the result is saved in: viral_test/yolo_detected/img_56.png
#  The image with the result is saved in: viral_test/yolo_detected/img_57.png
#  The image with the result is saved in: viral_test/yolo_detected/img_58.png
#  The image with the result is saved in: viral_test/yolo_detected/img_59.png
#  The image with the result is saved in: viral_test/yolo_detected/img_60.png
#  The image with the result is saved in: viral_test/yolo_detected/img_61.png
#  The image with the result is saved in: viral_test/yolo_detected/img_62.png
#  The image with the result is saved in: viral_test/yolo_detected/img_63.png
#  The image with the result is saved in: viral_test/yolo_detected/img_64.png
#  The image with the result is saved in: viral_test/yolo_detected/img_65.png
#  The image with the result is saved in: viral_test/yolo_detected/img_66.png
#  The image with the result is saved in: viral_test/yolo_detected/img_67.png
#  The image with the result is saved in: viral_test/yolo_detected/img_68.png
#  The image with the result is saved in: viral_test/yolo_detected/img_69.png
#  The image with the result is saved in: viral_test/yolo_detected/img_70.png
#  The image with the result is saved in: viral_test/yolo_detected/img_71.png
#  The image with the result is saved in: viral_test/yolo_detected/img_72.png
#  The image with the result is saved in: viral_test/yolo_detected/img_73.png
#  The image with the result is saved in: viral_test/yolo_detected/img_74.png
#  The image with the result is saved in: viral_test/yolo_detected/img_75.png
#  The image with the result is saved in: viral_test/yolo_detected/img_76.png
#  The image with the result is saved in: viral_test/yolo_detected/img_77.png
#  The image with the result is saved in: viral_test/yolo_detected/img_78.png
#  The image with the result is saved in: viral_test/yolo_detected/img_79.png
#  The image with the result is saved in: viral_test/yolo_detected/img_80.png
#  The image with the result is saved in: viral_test/yolo_detected/img_81.png
#  The image with the result is saved in: viral_test/yolo_detected/img_82.png
#  The image with the result is saved in: viral_test/yolo_detected/img_83.png
#  The image with the result is saved in: viral_test/yolo_detected/img_84.png
#  The image with the result is saved in: viral_test/yolo_detected/img_85.png
#  The image with the result is saved in: viral_test/yolo_detected/img_86.png
#  The image with the result is saved in: viral_test/yolo_detected/img_87.png
#  The image with the result is saved in: viral_test/yolo_detected/img_88.png
#  The image with the result is saved in: viral_test/yolo_detected/img_89.png
#  The image with the result is saved in: viral_test/yolo_detected/img_90.png
#  The image with the result is saved in: viral_test/yolo_detected/img_91.png
#  The image with the result is saved in: viral_test/yolo_detected/img_92.png
#  The image with the result is saved in: viral_test/yolo_detected/img_93.png
#  The image with the result is saved in: viral_test/yolo_detected/img_94.png
#  The image with the result is saved in: viral_test/yolo_detected/img_95.png
#  The image with the result is saved in: viral_test/yolo_detected/img_96.png
#  The image with the result is saved in: viral_test/yolo_detected/img_97.png
#  The image with the result is saved in: viral_test/yolo_detected/img_98.png
#  The image with the result is saved in: viral_test/yolo_detected/img_99.png
#  The image with the result is saved in: viral_test/yolo_detected/img_100.png
#  The image with the result is saved in: viral_test/yolo_detected/img_101.png
#  The image with the result is saved in: viral_test/yolo_detected/img_102.png
#  The image with the result is saved in: viral_test/yolo_detected/img_103.png
#  The image with the result is saved in: viral_test/yolo_detected/img_104.png
#  The image with the result is saved in: viral_test/yolo_detected/img_105.png
#  The image with the result is saved in: viral_test/yolo_detected/img_106.png
#  The image with the result is saved in: viral_test/yolo_detected/img_107.png
#  The image with the result is saved in: viral_test/yolo_detected/img_108.png
#  The image with the result is saved in: viral_test/yolo_detected/img_109.png
#  The image with the result is saved in: viral_test/yolo_detected/img_110.png
#  The image with the result is saved in: viral_test/yolo_detected/img_111.png
#  The image with the result is saved in: viral_test/yolo_detected/img_112.png
#  The image with the result is saved in: viral_test/yolo_detected/img_113.png
#  The image with the result is saved in: viral_test/yolo_detected/img_114.png
#  The image with the result is saved in: viral_test/yolo_detected/img_115.png
#  The image with the result is saved in: viral_test/yolo_detected/img_116.png
#  The image with the result is saved in: viral_test/yolo_detected/img_117.png
#  The image with the result is saved in: viral_test/yolo_detected/img_118.png
#  The image with the result is saved in: viral_test/yolo_detected/img_119.png
#  The image with the result is saved in: viral_test/yolo_detected/img_120.png
#  The image with the result is saved in: viral_test/yolo_detected/img_121.png
#  The image with the result is saved in: viral_test/yolo_detected/img_122.png
#  The image with the result is saved in: viral_test/yolo_detected/img_123.png
#  The image with the result is saved in: viral_test/yolo_detected/img_124.png
#  The image with the result is saved in: viral_test/yolo_detected/img_125.png
#  The image with the result is saved in: viral_test/yolo_detected/img_126.png
#  The image with the result is saved in: viral_test/yolo_detected/img_127.png
#  The image with the result is saved in: viral_test/yolo_detected/img_128.png
#  The image with the result is saved in: viral_test/yolo_detected/img_129.png
#  The image with the result is saved in: viral_test/yolo_detected/img_130.png
#  The image with the result is saved in: viral_test/yolo_detected/img_131.png
#  The image with the result is saved in: viral_test/yolo_detected/img_132.png
#  The image with the result is saved in: viral_test/yolo_detected/img_133.png
#  The image with the result is saved in: viral_test/yolo_detected/img_134.png
#  The image with the result is saved in: viral_test/yolo_detected/img_135.png
#  The image with the result is saved in: viral_test/yolo_detected/img_136.png
#  The image with the result is saved in: viral_test/yolo_detected/img_137.png
#  The image with the result is saved in: viral_test/yolo_detected/img_138.png
#  The image with the result is saved in: viral_test/yolo_detected/img_139.png
#  The image with the result is saved in: viral_test/yolo_detected/img_140.png
#  The image with the result is saved in: viral_test/yolo_detected/img_141.png
#  The image with the result is saved in: viral_test/yolo_detected/img_142.png
#  The image with the result is saved in: viral_test/yolo_detected/img_143.png
#  The image with the result is saved in: viral_test/yolo_detected/img_144.png
#  The image with the result is saved in: viral_test/yolo_detected/img_145.png
#  The image with the result is saved in: viral_test/yolo_detected/img_146.png
#  The image with the result is saved in: viral_test/yolo_detected/img_147.png
#  The image with the result is saved in: viral_test/yolo_detected/img_148.png
#  The image with the result is saved in: viral_test/yolo_detected/img_149.png
#  The image with the result is saved in: viral_test/yolo_detected/img_150.png
#  The image with the result is saved in: viral_test/yolo_detected/img_151.png
#  The image with the result is saved in: viral_test/yolo_detected/img_152.png
#  The image with the result is saved in: viral_test/yolo_detected/img_153.png
#  The image with the result is saved in: viral_test/yolo_detected/img_154.png
#  The image with the result is saved in: viral_test/yolo_detected/img_155.png
#  The image with the result is saved in: viral_test/yolo_detected/img_156.png
#  The image with the result is saved in: viral_test/yolo_detected/img_157.png
#  The image with the result is saved in: viral_test/yolo_detected/img_158.png
#  The image with the result is saved in: viral_test/yolo_detected/img_159.png
#  The image with the result is saved in: viral_test/yolo_detected/img_160.png
#  The image with the result is saved in: viral_test/yolo_detected/img_161.png
#  The image with the result is saved in: viral_test/yolo_detected/img_162.png
#  The image with the result is saved in: viral_test/yolo_detected/img_163.png
#  The image with the result is saved in: viral_test/yolo_detected/img_164.png
#  The image with the result is saved in: viral_test/yolo_detected/img_165.png
#  The image with the result is saved in: viral_test/yolo_detected/img_166.png
#  The image with the result is saved in: viral_test/yolo_detected/img_167.png
#  The image with the result is saved in: viral_test/yolo_detected/img_168.png
#  The image with the result is saved in: viral_test/yolo_detected/img_169.png
#  The image with the result is saved in: viral_test/yolo_detected/img_170.png
#  The image with the result is saved in: viral_test/yolo_detected/img_171.png
#  The image with the result is saved in: viral_test/yolo_detected/img_172.png
#  The image with the result is saved in: viral_test/yolo_detected/img_173.png
#  The image with the result is saved in: viral_test/yolo_detected/img_174.png
#  The image with the result is saved in: viral_test/yolo_detected/img_175.png
#  The image with the result is saved in: viral_test/yolo_detected/img_176.png
#  The image with the result is saved in: viral_test/yolo_detected/img_177.png
#  The image with the result is saved in: viral_test/yolo_detected/img_178.png
#  The image with the result is saved in: viral_test/yolo_detected/img_179.png
#  The image with the result is saved in: viral_test/yolo_detected/img_180.png
#  The image with the result is saved in: viral_test/yolo_detected/img_181.png
#  The image with the result is saved in: viral_test/yolo_detected/img_182.png
#  The image with the result is saved in: viral_test/yolo_detected/img_183.png
#  The image with the result is saved in: viral_test/yolo_detected/img_184.png
#  The image with the result is saved in: viral_test/yolo_detected/img_185.png
#  The image with the result is saved in: viral_test/yolo_detected/img_186.png
#  The image with the result is saved in: viral_test/yolo_detected/img_187.png
#  The image with the result is saved in: viral_test/yolo_detected/img_188.png
#  The image with the result is saved in: viral_test/yolo_detected/img_189.png
#  The image with the result is saved in: viral_test/yolo_detected/img_190.png
#  The image with the result is saved in: viral_test/yolo_detected/img_191.png
#  The image with the result is saved in: viral_test/yolo_detected/img_192.png
#  The image with the result is saved in: viral_test/yolo_detected/img_193.png
#  The image with the result is saved in: viral_test/yolo_detected/img_194.png
#  The image with the result is saved in: viral_test/yolo_detected/img_195.png
#  The image with the result is saved in: viral_test/yolo_detected/img_196.png
#  The image with the result is saved in: viral_test/yolo_detected/img_197.png
#  The image with the result is saved in: viral_test/yolo_detected/img_198.png
#  The image with the result is saved in: viral_test/yolo_detected/img_199.png
#  The image with the result is saved in: viral_test/yolo_detected/img_200.png
#  The image with the result is saved in: viral_test/yolo_detected/img_201.png
#  The image with the result is saved in: viral_test/yolo_detected/img_202.png
#  The image with the result is saved in: viral_test/yolo_detected/img_203.png
#  The image with the result is saved in: viral_test/yolo_detected/img_204.png
#  The image with the result is saved in: viral_test/yolo_detected/img_205.png
#  The image with the result is saved in: viral_test/yolo_detected/img_206.png
#  The image with the result is saved in: viral_test/yolo_detected/img_207.png
#  The image with the result is saved in: viral_test/yolo_detected/img_208.png
#  The image with the result is saved in: viral_test/yolo_detected/img_209.png
#  The image with the result is saved in: viral_test/yolo_detected/img_210.png
#  The image with the result is saved in: viral_test/yolo_detected/img_211.png
#  The image with the result is saved in: viral_test/yolo_detected/img_212.png
#  The image with the result is saved in: viral_test/yolo_detected/img_213.png
#  The image with the result is saved in: viral_test/yolo_detected/img_214.png
#  The image with the result is saved in: viral_test/yolo_detected/img_215.png
#  The image with the result is saved in: viral_test/yolo_detected/img_216.png
#  The image with the result is saved in: viral_test/yolo_detected/img_217.png
#  The image with the result is saved in: viral_test/yolo_detected/img_218.png
#  The image with the result is saved in: viral_test/yolo_detected/img_219.png
#  The image with the result is saved in: viral_test/yolo_detected/img_220.png
#  The image with the result is saved in: viral_test/yolo_detected/img_221.png
#  The image with the result is saved in: viral_test/yolo_detected/img_222.png
#  The image with the result is saved in: viral_test/yolo_detected/img_223.png
#  The image with the result is saved in: viral_test/yolo_detected/img_224.png
#  The image with the result is saved in: viral_test/yolo_detected/img_225.png
#  The image with the result is saved in: viral_test/yolo_detected/img_226.png
#  The image with the result is saved in: viral_test/yolo_detected/img_227.png
#  The image with the result is saved in: viral_test/yolo_detected/img_228.png
#  The image with the result is saved in: viral_test/yolo_detected/img_229.png
#  The image with the result is saved in: viral_test/yolo_detected/img_230.png
#  The image with the result is saved in: viral_test/yolo_detected/img_231.png
#  The image with the result is saved in: viral_test/yolo_detected/img_232.png
#  The image with the result is saved in: viral_test/yolo_detected/img_233.png
#  The image with the result is saved in: viral_test/yolo_detected/img_234.png
#  The image with the result is saved in: viral_test/yolo_detected/img_235.png
#  The image with the result is saved in: viral_test/yolo_detected/img_236.png
#  The image with the result is saved in: viral_test/yolo_detected/img_237.png
#  The image with the result is saved in: viral_test/yolo_detected/img_238.png
#  The image with the result is saved in: viral_test/yolo_detected/img_239.png
#  The image with the result is saved in: viral_test/yolo_detected/img_240.png
#  The image with the result is saved in: viral_test/yolo_detected/img_241.png
#  The image with the result is saved in: viral_test/yolo_detected/img_242.png
#  The image with the result is saved in: viral_test/yolo_detected/img_243.png
#  The image with the result is saved in: viral_test/yolo_detected/img_244.png
#  The image with the result is saved in: viral_test/yolo_detected/img_245.png
#  The image with the result is saved in: viral_test/yolo_detected/img_246.png
#  The image with the result is saved in: viral_test/yolo_detected/img_247.png
#  The image with the result is saved in: viral_test/yolo_detected/img_248.png
#  The image with the result is saved in: viral_test/yolo_detected/img_249.png
#  The image with the result is saved in: viral_test/yolo_detected/img_250.png
#  The image with the result is saved in: viral_test/yolo_detected/img_251.png
#  The image with the result is saved in: viral_test/yolo_detected/img_252.png
#  The image with the result is saved in: viral_test/yolo_detected/img_253.png
#  The image with the result is saved in: viral_test/yolo_detected/img_254.png
#  The image with the result is saved in: viral_test/yolo_detected/img_255.png
#  The image with the result is saved in: viral_test/yolo_detected/img_256.png
#  The image with the result is saved in: viral_test/yolo_detected/img_257.png
#  The image with the result is saved in: viral_test/yolo_detected/img_258.png
#  The image with the result is saved in: viral_test/yolo_detected/img_259.png
#  The image with the result is saved in: viral_test/yolo_detected/img_260.png
#  The image with the result is saved in: viral_test/yolo_detected/img_261.png
#  The image with the result is saved in: viral_test/yolo_detected/img_262.png
#  The image with the result is saved in: viral_test/yolo_detected/img_263.png
#  The image with the result is saved in: viral_test/yolo_detected/img_264.png
#  The image with the result is saved in: viral_test/yolo_detected/img_265.png
#  The image with the result is saved in: viral_test/yolo_detected/img_266.png
#  The image with the result is saved in: viral_test/yolo_detected/img_267.png
#  The image with the result is saved in: viral_test/yolo_detected/img_268.png
#  The image with the result is saved in: viral_test/yolo_detected/img_269.png
#  The image with the result is saved in: viral_test/yolo_detected/img_270.png
#  The image with the result is saved in: viral_test/yolo_detected/img_271.png
#  The image with the result is saved in: viral_test/yolo_detected/img_272.png
#  The image with the result is saved in: viral_test/yolo_detected/img_273.png
#  The image with the result is saved in: viral_test/yolo_detected/img_274.png
#  The image with the result is saved in: viral_test/yolo_detected/img_275.png
#  The image with the result is saved in: viral_test/yolo_detected/img_276.png
#  The image with the result is saved in: viral_test/yolo_detected/img_277.png
#  The image with the result is saved in: viral_test/yolo_detected/img_278.png
#  The image with the result is saved in: viral_test/yolo_detected/img_279.png
#  The image with the result is saved in: viral_test/yolo_detected/img_280.png
#  The image with the result is saved in: viral_test/yolo_detected/img_281.png
#  The image with the result is saved in: viral_test/yolo_detected/img_282.png
#  The image with the result is saved in: viral_test/yolo_detected/img_283.png
#  The image with the result is saved in: viral_test/yolo_detected/img_284.png
#  The image with the result is saved in: viral_test/yolo_detected/img_285.png
#  The image with the result is saved in: viral_test/yolo_detected/img_286.png
#  The image with the result is saved in: viral_test/yolo_detected/img_287.png
#  The image with the result is saved in: viral_test/yolo_detected/img_288.png
#  The image with the result is saved in: viral_test/yolo_detected/img_289.png
#  The image with the result is saved in: viral_test/yolo_detected/img_290.png
#  The image with the result is saved in: viral_test/yolo_detected/img_291.png
#  The image with the result is saved in: viral_test/yolo_detected/img_292.png
#  The image with the result is saved in: viral_test/yolo_detected/img_293.png
#  The image with the result is saved in: viral_test/yolo_detected/img_294.png
#  The image with the result is saved in: viral_test/yolo_detected/img_295.png
#  The image with the result is saved in: viral_test/yolo_detected/img_296.png
#  The image with the result is saved in: viral_test/yolo_detected/img_297.png
#  The image with the result is saved in: viral_test/yolo_detected/img_298.png
#  The image with the result is saved in: viral_test/yolo_detected/img_299.png
#  The image with the result is saved in: viral_test/yolo_detected/img_300.png
#  The image with the result is saved in: viral_test/yolo_detected/img_301.png
#  The image with the result is saved in: viral_test/yolo_detected/img_302.png
#  The image with the result is saved in: viral_test/yolo_detected/img_303.png
#  The image with the result is saved in: viral_test/yolo_detected/img_304.png
#  The image with the result is saved in: viral_test/yolo_detected/img_305.png
#  The image with the result is saved in: viral_test/yolo_detected/img_306.png
#  The image with the result is saved in: viral_test/yolo_detected/img_307.png
#  The image with the result is saved in: viral_test/yolo_detected/img_308.png
#  The image with the result is saved in: viral_test/yolo_detected/img_309.png
#  The image with the result is saved in: viral_test/yolo_detected/img_310.png
#  The image with the result is saved in: viral_test/yolo_detected/img_311.png
#  The image with the result is saved in: viral_test/yolo_detected/img_312.png
#  The image with the result is saved in: viral_test/yolo_detected/img_313.png
#  The image with the result is saved in: viral_test/yolo_detected/img_314.png
#  The image with the result is saved in: viral_test/yolo_detected/img_315.png
#  The image with the result is saved in: viral_test/yolo_detected/img_316.png
#  The image with the result is saved in: viral_test/yolo_detected/img_317.png
#  The image with the result is saved in: viral_test/yolo_detected/img_318.png
#  The image with the result is saved in: viral_test/yolo_detected/img_319.png
#  The image with the result is saved in: viral_test/yolo_detected/img_320.png
#  The image with the result is saved in: viral_test/yolo_detected/img_321.png
#  The image with the result is saved in: viral_test/yolo_detected/img_322.png
#  The image with the result is saved in: viral_test/yolo_detected/img_323.png
#  The image with the result is saved in: viral_test/yolo_detected/img_324.png
#  The image with the result is saved in: viral_test/yolo_detected/img_325.png
#  The image with the result is saved in: viral_test/yolo_detected/img_326.png
#  The image with the result is saved in: viral_test/yolo_detected/img_327.png
#  The image with the result is saved in: viral_test/yolo_detected/img_328.png
#  The image with the result is saved in: viral_test/yolo_detected/img_329.png
#  The image with the result is saved in: viral_test/yolo_detected/img_330.png
#  The image with the result is saved in: viral_test/yolo_detected/img_331.png
#  The image with the result is saved in: viral_test/yolo_detected/img_332.png
#  The image with the result is saved in: viral_test/yolo_detected/img_333.png
#  The image with the result is saved in: viral_test/yolo_detected/img_334.png
#  The image with the result is saved in: viral_test/yolo_detected/img_335.png
#  The image with the result is saved in: viral_test/yolo_detected/img_336.png
#  The image with the result is saved in: viral_test/yolo_detected/img_337.png
#  The image with the result is saved in: viral_test/yolo_detected/img_338.png
#  The image with the result is saved in: viral_test/yolo_detected/img_339.png
#  The image with the result is saved in: viral_test/yolo_detected/img_340.png
#  The image with the result is saved in: viral_test/yolo_detected/img_341.png
#  The image with the result is saved in: viral_test/yolo_detected/img_342.png
#  The image with the result is saved in: viral_test/yolo_detected/img_343.png
#  The image with the result is saved in: viral_test/yolo_detected/img_344.png
#  The image with the result is saved in: viral_test/yolo_detected/img_345.png
#  The image with the result is saved in: viral_test/yolo_detected/img_346.png
#  The image with the result is saved in: viral_test/yolo_detected/img_347.png
#  The image with the result is saved in: viral_test/yolo_detected/img_348.png
#  The image with the result is saved in: viral_test/yolo_detected/img_349.png
#  The image with the result is saved in: viral_test/yolo_detected/img_350.png
#  The image with the result is saved in: viral_test/yolo_detected/img_351.png
#  The image with the result is saved in: viral_test/yolo_detected/img_352.png
#  The image with the result is saved in: viral_test/yolo_detected/img_353.png
#  The image with the result is saved in: viral_test/yolo_detected/img_354.png
#  The image with the result is saved in: viral_test/yolo_detected/img_355.png
#  The image with the result is saved in: viral_test/yolo_detected/img_356.png
#  The image with the result is saved in: viral_test/yolo_detected/img_357.png
#  The image with the result is saved in: viral_test/yolo_detected/img_358.png
#  The image with the result is saved in: viral_test/yolo_detected/img_359.png
#  The image with the result is saved in: viral_test/yolo_detected/img_360.png
#  The image with the result is saved in: viral_test/yolo_detected/img_361.png
#  The image with the result is saved in: viral_test/yolo_detected/img_362.png
#  The image with the result is saved in: viral_test/yolo_detected/img_363.png
#  The image with the result is saved in: viral_test/yolo_detected/img_364.png
#  The image with the result is saved in: viral_test/yolo_detected/img_365.png
#  The image with the result is saved in: viral_test/yolo_detected/img_366.png
#  The image with the result is saved in: viral_test/yolo_detected/img_367.png
#  The image with the result is saved in: viral_test/yolo_detected/img_368.png
#  The image with the result is saved in: viral_test/yolo_detected/img_369.png
#  The image with the result is saved in: viral_test/yolo_detected/img_370.png
#  The image with the result is saved in: viral_test/yolo_detected/img_371.png
#  The image with the result is saved in: viral_test/yolo_detected/img_372.png
#  The image with the result is saved in: viral_test/yolo_detected/img_373.png
#  The image with the result is saved in: viral_test/yolo_detected/img_374.png
#  The image with the result is saved in: viral_test/yolo_detected/img_375.png
#  The image with the result is saved in: viral_test/yolo_detected/img_376.png
#  The image with the result is saved in: viral_test/yolo_detected/img_377.png
#  The image with the result is saved in: viral_test/yolo_detected/img_378.png
#  The image with the result is saved in: viral_test/yolo_detected/img_379.png
#  The image with the result is saved in: viral_test/yolo_detected/img_380.png
#  The image with the result is saved in: viral_test/yolo_detected/img_381.png
#  The image with the result is saved in: viral_test/yolo_detected/img_382.png
#  The image with the result is saved in: viral_test/yolo_detected/img_383.png
#  The image with the result is saved in: viral_test/yolo_detected/img_384.png
#  The image with the result is saved in: viral_test/yolo_detected/img_385.png
#  The image with the result is saved in: viral_test/yolo_detected/img_386.png
#  The image with the result is saved in: viral_test/yolo_detected/img_387.png
#  The image with the result is saved in: viral_test/yolo_detected/img_388.png
#  The image with the result is saved in: viral_test/yolo_detected/img_389.png
#  The image with the result is saved in: viral_test/yolo_detected/img_390.png
#  The image with the result is saved in: viral_test/yolo_detected/img_391.png
#  The image with the result is saved in: viral_test/yolo_detected/img_392.png
#  The image with the result is saved in: viral_test/yolo_detected/img_393.png
#  The image with the result is saved in: viral_test/yolo_detected/img_394.png
#  The image with the result is saved in: viral_test/yolo_detected/img_395.png
#  The image with the result is saved in: viral_test/yolo_detected/img_396.png
#  The image with the result is saved in: viral_test/yolo_detected/img_397.png
#  The image with the result is saved in: viral_test/yolo_detected/img_398.png
#  The image with the result is saved in: viral_test/yolo_detected/img_399.png
#  The image with the result is saved in: viral_test/yolo_detected/img_400.png
#  The image with the result is saved in: viral_test/yolo_detected/img_401.png
#  The image with the result is saved in: viral_test/yolo_detected/img_402.png
#  The image with the result is saved in: viral_test/yolo_detected/img_403.png
#  The image with the result is saved in: viral_test/yolo_detected/img_404.png
#  The image with the result is saved in: viral_test/yolo_detected/img_405.png
#  The image with the result is saved in: viral_test/yolo_detected/img_406.png
#  The image with the result is saved in: viral_test/yolo_detected/img_407.png
#  The image with the result is saved in: viral_test/yolo_detected/img_408.png
#  The image with the result is saved in: viral_test/yolo_detected/img_409.png
#  The image with the result is saved in: viral_test/yolo_detected/img_410.png
#  The image with the result is saved in: viral_test/yolo_detected/img_411.png
#  The image with the result is saved in: viral_test/yolo_detected/img_412.png
#  The image with the result is saved in: viral_test/yolo_detected/img_413.png
#  The image with the result is saved in: viral_test/yolo_detected/img_414.png
#  The image with the result is saved in: viral_test/yolo_detected/img_415.png
#  The image with the result is saved in: viral_test/yolo_detected/img_416.png
#  The image with the result is saved in: viral_test/yolo_detected/img_417.png
#  The image with the result is saved in: viral_test/yolo_detected/img_418.png
#  The image with the result is saved in: viral_test/yolo_detected/img_419.png
#  The image with the result is saved in: viral_test/yolo_detected/img_420.png
#  The image with the result is saved in: viral_test/yolo_detected/img_421.png
#  The image with the result is saved in: viral_test/yolo_detected/img_422.png
#  The image with the result is saved in: viral_test/yolo_detected/img_423.png
#  The image with the result is saved in: viral_test/yolo_detected/img_424.png
#  The image with the result is saved in: viral_test/yolo_detected/img_425.png
#  The image with the result is saved in: viral_test/yolo_detected/img_426.png
#  The image with the result is saved in: viral_test/yolo_detected/img_427.png
#  The image with the result is saved in: viral_test/yolo_detected/img_428.png
#  The image with the result is saved in: viral_test/yolo_detected/img_429.png
#  The image with the result is saved in: viral_test/yolo_detected/img_430.png
#  The image with the result is saved in: viral_test/yolo_detected/img_431.png
#  The image with the result is saved in: viral_test/yolo_detected/img_432.png
#  The image with the result is saved in: viral_test/yolo_detected/img_433.png
#  The image with the result is saved in: viral_test/yolo_detected/img_434.png
#  The image with the result is saved in: viral_test/yolo_detected/img_435.png
#  The image with the result is saved in: viral_test/yolo_detected/img_436.png
#  The image with the result is saved in: viral_test/yolo_detected/img_437.png
#  The image with the result is saved in: viral_test/yolo_detected/img_438.png
#  The image with the result is saved in: viral_test/yolo_detected/img_439.png
#  The image with the result is saved in: viral_test/yolo_detected/img_440.png

# %%
file_json
# Out:
# {"crs": {"properties": {"name": "urn:ogc:def:crs:EPSG::32638"}, "type": "name"}, "features": [{"geometry": {"coordinates": [[[657148.366912, 2715810.100217], [657152.169251, 2715810.100217], [657152.169251, 2715805.827112], [657148.366912, 2715805.827112], [657148.366912, 2715810.100217]]], "type": "Polygon"}, "properties": {"Polyg_Area": 16.247793893440843, "area": 16.247793893440843, "height": 4.273104903753847, "id": 0, "perimeter": 32.495587786881686, "width": 3.8023391092428938}, "type": "Feature"}, {"geometry": {"coordinates": [[[657162.236397, 2715802.531752], [657165.495544, 2715802.531752], [657165.495544, 2715797.425754], [657162.236397, 2715797.425754], [657162.236397, 2715802.531752]]], "type": "Polygon"}, "properties": {"Polyg_Area": 16.641202944750027, "area": 16.641202944750027, "height": 5.105998232029378, "id": 1, "perimeter": 33.282405889500055, "width": 3.2591478078393266}, "type": "Feature"}, {"geometry": {"coordinates": [[[657153.907463, 2715805.754687], [657157.601164, 2715805.754687], [657157.601164, 2715801.228093], [657153.907463, 2715801.228093], [657153.907463, 2715805.754687]]], "type": "Polygon"}, "properties": {"Polyg_Area": 16.719884757520216, "area": 16.719884757520216, "height": 4.5265941778197885, "id": 2, "perimeter": 33.43976951504043, "width": 3.6937008489621803}, "type": "Feature"}, {"geometry": {"coordinates": [[[657154.776569, 2715810.172643], [657159.882568, 2715810.172643], [657159.882568, 2715804.958006], [657154.776569, 2715804.958006], [657154.776569, 2715810.172643]]], "type": "Polygon"}, "properties": {"Polyg_Area": 26.6259247157989, "area": 26.6259247157989, "height": 5.214636493008584, "id": 3, "perimeter": 53.2518494315978, "width": 5.105998232378624}, "type": "Feature"}, {"geometry": {"coordinates": [[[657150.793166, 2715812.888599], [657155.464612, 2715812.888599], [657155.464612, 2715807.565325], [657150.793166, 2715807.565325], [657150.793166, 2715812.888599]]], "type": "Polygon"}, "properties": {"Polyg_Area": 24.86738624534328, "area": 24.86738624534328, "height": 5.323274752590805, "id": 4, "perimeter": 49.73477249068656, "width": 4.671445191372186}, "type": "Feature"}, {"geometry": {"coordinates": [[[657170.16699, 2715802.64039], [657173.426137, 2715802.64039], [657173.426137, 2715799.127753], [657170.16699, 2715799.127753], [657170.16699, 2715802.64039]]], "type": "Polygon"}, "properties": {"Polyg_Area": 11.448203446015023, "area": 11.448203446015023, "height": 3.5126370820216835, "id": 5, "perimeter": 22.896406892030047, "width": 3.259147807955742}, "type": "Feature"}, {"geometry": {"coordinates": [[[657159.665291, 2715801.010816], [657163.177928, 2715801.010816], [657163.177928, 2715796.59286], [657159.665291, 2715796.59286], [657159.665291, 2715801.010816]]], "type": "Polygon"}, "properties": {"Polyg_Area": 15.5186757808384, "area": 15.5186757808384, "height": 4.417955917306244, "id": 6, "perimeter": 31.0373515616768, "width": 3.512637081788853}, "type": "Feature"}, {"geometry": {"coordinates": [[[657151.951975, 2715800.322774], [657155.862952, 2715800.322774], [657155.862952, 2715796.375584], [657151.951975, 2715796.375584], [657151.951975, 2715800.322774]]], "type": "Polygon"}, "properties": {"Polyg_Area": 15.437371243004195, "area": 15.437371243004195, "height": 3.947190122678876, "id": 7, "perimeter": 30.87474248600839, "width": 3.910977369523607}, "type": "Feature"}, {"geometry": {"coordinates": [[[657149.199805, 2715818.429151], [657154.450655, 2715818.429151], [657154.450655, 2715812.200557], [657149.199805, 2715812.200557], [657149.199805, 2715818.429151]]], "type": "Polygon"}, "properties": {"Polyg_Area": 32.70540594800149, "area": 32.70540594800149, "height": 6.2285935883410275, "id": 8, "perimeter": 65.41081189600298, "width": 5.2508492461638525}, "type": "Feature"}, {"geometry": {"coordinates": [[[657157.67359, 2715805.573623], [657162.01912, 2715805.573623], [657162.01912, 2715800.358987], [657157.67359, 2715800.358987], [657157.67359, 2715805.573623]]], ...
